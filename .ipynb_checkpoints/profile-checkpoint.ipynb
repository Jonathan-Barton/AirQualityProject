# %%
import pandas as pd
import scipy as sc
from scipy.stats import norm

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (20, 6)
plt.style.use('ggplot')

# %%
aircalifornia = pd.read_csv(
    'NO2_2020_California.csv', 
    index_col='Date',
    parse_dates=["Date"],
)

# %%
aircalifornia.head()
#aircalifornia.info()  #total 28121 records for the whole 2020 year
# Out:
#            Source   Site ID  POC  Daily Max 1-hour NO2 Concentration UNITS  \
# Date
# 2020-01-01    AQS  60010007    1                                18.5   ppb
# 2020-01-02    AQS  60010007    1                                22.7   ppb
# 2020-01-03    AQS  60010007    1                                23.6   ppb
# 2020-01-04    AQS  60010007    1                                21.2   ppb
# 2020-01-05    AQS  60010007    1                                23.0   ppb
#
#             DAILY_AQI_VALUE  Site Name  DAILY_OBS_COUNT  PERCENT_COMPLETE  \
# Date
# 2020-01-01               17  Livermore               23              96.0
# 2020-01-02               21  Livermore               23              96.0
# 2020-01-03               22  Livermore               23              96.0
# 2020-01-04               20  Livermore               23              96.0
# 2020-01-05               22  Livermore               23              96.0
#
#             AQS_PARAMETER_CODE      AQS_PARAMETER_DESC  CBSA_CODE  \
# Date
# 2020-01-01               42602  Nitrogen dioxide (NO2)      41860
# 2020-01-02               42602  Nitrogen dioxide (NO2)      41860
# 2020-01-03               42602  Nitrogen dioxide (NO2)      41860
# 2020-01-04               42602  Nitrogen dioxide (NO2)      41860
# 2020-01-05               42602  Nitrogen dioxide (NO2)      41860
#
#                                     CBSA_NAME  STATE_CODE       STATE  \
# Date
# 2020-01-01  San Francisco-Oakland-Hayward, CA           6  California
# 2020-01-02  San Francisco-Oakland-Hayward, CA           6  California
# 2020-01-03  San Francisco-Oakland-Hayward, CA           6  California
# 2020-01-04  San Francisco-Oakland-Hayward, CA           6  California
# 2020-01-05  San Francisco-Oakland-Hayward, CA           6  California
#
#             COUNTY_CODE   COUNTY  SITE_LATITUDE  SITE_LONGITUDE
# Date
# 2020-01-01            1  Alameda      37.687526     -121.784217
# 2020-01-02            1  Alameda      37.687526     -121.784217
# 2020-01-03            1  Alameda      37.687526     -121.784217
# 2020-01-04            1  Alameda      37.687526     -121.784217
# 2020-01-05            1  Alameda      37.687526     -121.784217

# %%
datemask = aircalifornia.loc['2020-05-01':'2020-12-31']  #select date series
datemask.head()
datemask.describe()
counties = datemask.sort_values("COUNTY").groupby("COUNTY")
counties.tail()
countysize = counties.size() #how many records for each countyprint()
print(countysize)

datemask["COUNTY"].value_counts().plot(kind='bar')
plt.suptitle('Records amount for each county in California',fontsize=14)
plt.show()   #can use this histogram to choose counties

print(countysize.count())  #total 32 counties
# Out:
#             Site ID           POC  Daily Max 1-hour NO2 Concentration  \
# count  1.668500e+04  16685.000000                        16685.000000
# mean   6.054337e+07      1.219718                           16.473623
# std    2.898326e+05      0.649701                           13.016209
# min    6.001001e+07      1.000000                           -2.000000
# 25%    6.037011e+07      1.000000                            6.600000
# 50%    6.065001e+07      1.000000                           13.000000
# 75%    6.073102e+07      1.000000                           23.100000
# max    6.113000e+07      5.000000                          101.600000
#
#        DAILY_AQI_VALUE  DAILY_OBS_COUNT  PERCENT_COMPLETE  AQS_PARAMETER_CODE  \
# count     16685.000000     16685.000000      16685.000000             16685.0
# mean         15.249146        23.077315         96.281031             42602.0
# std          12.246723         1.000308          4.110915                 0.0
# min           0.000000        18.000000         75.000000             42602.0
# 25%           6.000000        23.000000         96.000000             42602.0
# 50%          12.000000        23.000000         96.000000             42602.0
# 75%          22.000000        24.000000        100.000000             42602.0
# max         101.000000        24.000000        100.000000             42602.0
#
#           CBSA_CODE  STATE_CODE   COUNTY_CODE  SITE_LATITUDE  SITE_LONGITUDE
# count  16685.000000     16685.0  16685.000000   16685.000000    16685.000000
# mean   37085.692538         6.0     54.175427      35.634420     -119.534197
# std     6741.038110         0.0     28.956837       2.047349        2.067513
# min    12540.000000         6.0      1.000000      32.578160     -124.179490
# 25%    31080.000000         6.0     37.000000      33.999580     -121.641918
# 50%    40140.000000         6.0     65.000000      34.541660     -119.143182
# 75%    41860.000000         6.0     73.000000      37.743065     -117.617220
# max    49700.000000         6.0    113.000000      40.776780     -115.563060

# %%
airno2 = counties["Daily Max 1-hour NO2 Concentration"].mean()
airaqi = counties["DAILY_AQI_VALUE"].mean()
print(airno2)
print(airaqi)
ax = pd.concat([airno2, airaqi], axis=1).plot()
ax.set_xticks(range(len(counties)))
ax.set_xticklabels(counties.groups.keys(), rotation=45)
ax.legend(["Daily Max 1-hour NO2 Concentration(ppb)", "Daily AQI Value"])
print()
# Out:
# COUNTY
# Alameda            18.852208
# Butte               8.923490
# Contra Costa        9.886908
# Fresno             15.571512
# Humboldt            5.331718
# Imperial           12.529730
# Kern               23.942222
# Kings              13.714667
# Los Angeles        22.338175
# Madera              8.441111
# Marin              12.648598
# Merced             12.633113
# Monterey            6.339869
# Napa                8.972772
# Orange             24.421199
# Placer              9.871053
# Riverside          18.594498
# Sacramento         11.250733
# San Bernardino     31.700439
# San Diego          11.621302
# San Francisco      13.913615
# San Joaquin        13.229545
# San Luis Obispo     6.884615
# San Mateo          13.673364
# Santa Barbara       2.956379
# Santa Clara        19.825000
# Solano             12.740845
# Sonoma              6.899057
# Stanislaus         15.972549
# Sutter             10.495946
# Ventura            13.219462
# Yolo                8.535762
# Name: Daily Max 1-hour NO2 Concentration, dtype: float64
# COUNTY
# Alameda            17.358044
# Butte               8.073826
# Contra Costa        8.998753
# Fresno             14.268464
# Humboldt            4.682819
# Imperial           11.331081
# Kern               22.155556
# Kings              12.526667
# Los Angeles        20.645620
# Madera              7.655556
# Marin              11.542056
# Merced             11.509934
# Monterey            6.052288
# Napa                8.074257
# Orange             22.601116
# Placer              9.019737
# Riverside          17.144498
# Sacramento         10.574780
# San Bernardino     29.579795
# San Diego          11.007608
# San Francisco      12.793427
# San Joaquin        12.049242
# San Luis Obispo     6.594872
# San Mateo          12.528037
# Santa Barbara       2.910578
# Santa Clara        18.250000
# Solano             11.690141
# Sonoma              6.198113
# Stanislaus         14.666667
# Sutter              9.554054
# Ventura            12.488613
# Yolo                7.735099
# Name: DAILY_AQI_VALUE, dtype: float64
